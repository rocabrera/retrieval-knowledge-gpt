# %%
import pandas as pd
from pathlib import Path

# %%
path = Path.cwd().parent / "data/hemophilia/results/flan_t5_xl_questions.csv"
path
# Out:
# PosixPath('/home/rocabrera/Desktop/retrieval-knowledge-gpt/data/hemophilia/results/flan_t5_xl_questions.csv')

# %%
df = pd.read_csv(path)

# %%
def print_retrieval_vs_normal(sample):
    
    print("Question:")
    print(sample["question"])
    print("With retrieval:")
    print(sample["with_retrieval_answer"])
    print("Without retrieval:")
    print(sample["without_retrieval_answer"])
    print("#" * 64)

# %%
_= df.apply(print_retrieval_vs_normal, axis=1)
# Out:
# Question:
# What is hemophilia?
# With retrieval:
# a group of bleeding disorders in which there is a deficiency of one of
# Without retrieval:
# a disease in which the body does not produce enough red blood cells
# ################################################################
# Question:
# What causes hemophilia?
# With retrieval:
# mutations in coagulation factor VIII
# Without retrieval:
# a deficiency of a protein
# ################################################################
# Question:
# Is hemophilia genetic?
# With retrieval:
# yes
# Without retrieval:
# Yes
# ################################################################
# Question:
# nan
# With retrieval:
# nan
# Without retrieval:
# nan
# ################################################################
# Question:
# nan
# With retrieval:
# nan
# Without retrieval:
# nan
# ################################################################
# Question:
# nan
# With retrieval:
# nan
# Without retrieval:
# nan
# ################################################################
# Question:
# nan
# With retrieval:
# nan
# Without retrieval:
# nan
# ################################################################
# Question:
# How is hemophilia diagnosed?
# With retrieval:
# by determination of the amount of FVIII:C in the blood
# Without retrieval:
# Hemophilia is diagnosed by a blood test.
# ################################################################
# Question:
# nan
# With retrieval:
# nan
# Without retrieval:
# nan
# ################################################################
# Question:
# nan
# With retrieval:
# nan
# Without retrieval:
# nan
# ################################################################
# Question:
# How is hemophilia managed?
# With retrieval:
# by specially trained staff in modern, comprehensive care centres
# Without retrieval:
# Hemophilia is managed by a bone marrow transplant.
# ################################################################
# Question:
# nan
# With retrieval:
# nan
# Without retrieval:
# nan
# ################################################################
# Question:
# nan
# With retrieval:
# nan
# Without retrieval:
# nan
# ################################################################
# Question:
# nan
# With retrieval:
# nan
# Without retrieval:
# nan
# ################################################################
# Question:
# nan
# With retrieval:
# nan
# Without retrieval:
# nan
# ################################################################
# Question:
# nan
# With retrieval:
# nan
# Without retrieval:
# nan
# ################################################################
# Question:
# nan
# With retrieval:
# nan
# Without retrieval:
# nan
# ################################################################
# Question:
# nan
# With retrieval:
# nan
# Without retrieval:
# nan
# ################################################################
# Question:
# nan
# With retrieval:
# nan
# Without retrieval:
# nan
# ################################################################
# Question:
# nan
# With retrieval:
# nan
# Without retrieval:
# nan
# ################################################################
# Question:
# nan
# With retrieval:
# nan
# Without retrieval:
# nan
# ################################################################
# Question:
# nan
# With retrieval:
# nan
# Without retrieval:
# nan
# ################################################################
# Question:
# nan
# With retrieval:
# nan
# Without retrieval:
# nan
# ################################################################
# Question:
# nan
# With retrieval:
# nan
# Without retrieval:
# nan
# ################################################################
# Question:
# nan
# With retrieval:
# nan
# Without retrieval:
# nan
# ################################################################
# Question:
# How is an inhibitor treated?
# With retrieval:
# Antibody eradication, by way of immune tolerance induction (ITI), is still
# Without retrieval:
# It is treated by a pharmacological agent.
# ################################################################
# Question:
# nan
# With retrieval:
# nan
# Without retrieval:
# nan
# ################################################################
# Question:
# nan
# With retrieval:
# nan
# Without retrieval:
# nan
# ################################################################
# Question:
# nan
# With retrieval:
# nan
# Without retrieval:
# nan
# ################################################################
# Question:
# nan
# With retrieval:
# nan
# Without retrieval:
# nan
# ################################################################
# Question:
# nan
# With retrieval:
# nan
# Without retrieval:
# nan
# ################################################################
# Question:
# nan
# With retrieval:
# nan
# Without retrieval:
# nan
# ################################################################
# Question:
# nan
# With retrieval:
# nan
# Without retrieval:
# nan
# ################################################################
# Question:
# nan
# With retrieval:
# nan
# Without retrieval:
# nan
# ################################################################
# Question:
# nan
# With retrieval:
# nan
# Without retrieval:
# nan
# ################################################################
# Question:
# nan
# With retrieval:
# nan
# Without retrieval:
# nan
# ################################################################
# Question:
# nan
# With retrieval:
# nan
# Without retrieval:
# nan
# ################################################################
# Question:
# nan
# With retrieval:
# nan
# Without retrieval:
# nan
# ################################################################
# Question:
# nan
# With retrieval:
# nan
# Without retrieval:
# nan
# ################################################################
# Question:
# nan
# With retrieval:
# nan
# Without retrieval:
# nan
# ################################################################
# Question:
# nan
# With retrieval:
# nan
# Without retrieval:
# nan
# ################################################################
# Question:
# nan
# With retrieval:
# nan
# Without retrieval:
# nan
# ################################################################
# Question:
# nan
# With retrieval:
# nan
# Without retrieval:
# nan
# ################################################################
# Question:
# nan
# With retrieval:
# nan
# Without retrieval:
# nan
# ################################################################
# Question:
# nan
# With retrieval:
# nan
# Without retrieval:
# nan
# ################################################################
# Question:
# nan
# With retrieval:
# nan
# Without retrieval:
# nan
# ################################################################
# Question:
# How can psychological support help people with hemophilia?
# With retrieval:
# promoting emotional well-being, QoL and pain control
# Without retrieval:
# Help them cope with the difficulties of their condition
# ################################################################
# Question:
# What is the role of nutrition in hemophilia?
# With retrieval:
# iron
# Without retrieval:
# preventing the clotting of blood
# ################################################################
# Question:
# nan
# With retrieval:
# nan
# Without retrieval:
# nan
# ################################################################
# Question:
# nan
# With retrieval:
# nan
# Without retrieval:
# nan
# ################################################################
# Question:
# nan
# With retrieval:
# nan
# Without retrieval:
# nan
# ################################################################
# Question:
# nan
# With retrieval:
# nan
# Without retrieval:
# nan
# ################################################################
# Question:
# nan
# With retrieval:
# nan
# Without retrieval:
# nan
# ################################################################
# Question:
# nan
# With retrieval:
# nan
# Without retrieval:
# nan
# ################################################################
# Question:
# nan
# With retrieval:
# nan
# Without retrieval:
# nan
# ################################################################
# Question:
# What are the symptoms of von Willebrand disease?
# With retrieval:
# ecchymoses-hematomas and epistaxis and,
# Without retrieval:
# bleeding
# ################################################################
# Question:
# How is von Willebrand disease diagnosed?
# With retrieval:
# A complete evaluation including von Willebrand factor multimers, ristocetin-induced plate
# Without retrieval:
# It is diagnosed by a blood test that shows a lack of von Willebrand factor
# ################################################################
# Question:
# nan
# With retrieval:
# nan
# Without retrieval:
# nan
# ################################################################
# Question:
# nan
# With retrieval:
# nan
# Without retrieval:
# nan
# ################################################################
# Question:
# nan
# With retrieval:
# nan
# Without retrieval:
# nan
# ################################################################
# Question:
# nan
# With retrieval:
# nan
# Without retrieval:
# nan
# ################################################################
# Question:
# nan
# With retrieval:
# nan
# Without retrieval:
# nan
# ################################################################
# Question:
# nan
# With retrieval:
# nan
# Without retrieval:
# nan
# ################################################################
# Question:
# nan
# With retrieval:
# nan
# Without retrieval:
# nan
# ################################################################
# Question:
# nan
# With retrieval:
# nan
# Without retrieval:
# nan
# ################################################################
# Question:
# nan
# With retrieval:
# nan
# Without retrieval:
# nan
# ################################################################
# Question:
# nan
# With retrieval:
# nan
# Without retrieval:
# nan
# ################################################################
# Question:
# nan
# With retrieval:
# nan
# Without retrieval:
# nan
# ################################################################
# Question:
# nan
# With retrieval:
# nan
# Without retrieval:
# nan
# ################################################################
# Question:
# nan
# With retrieval:
# nan
# Without retrieval:
# nan
# ################################################################
